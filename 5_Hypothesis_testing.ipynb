# %% [markdown]
# <div style="text-align: center; font-size: 46px; color: blue;">
#     <u><b>5.HYPOTHESIS TESTING</b></u>
# </div>

# %% [markdown]
# <div style="text-align: center; font-size: 30px; color: Violet;">
#     <u><b>For Weekly Operating Costs</b></u>
# </div>

# %% [markdown]
# ## Objective:
# #### To investigate the restaurant owners' claim about the increase in weekly operating costs using hypothesis testing.

# %% [markdown]
# ## Data
# #### •	The theoretical weekly operating cost model: W = $1,000 + $5X
# #### •	Sample of 25 restaurants with a mean weekly cost of Rs. 3,050
# #### •	Number of units produced in a week (X) follows a normal distribution with a mean (μ) of 600 units and a standard deviation (σ) of 25 units

# %%
import scipy.stats as stats

# %% [markdown]
# ## Assignments tasks:

# %%
### 1. State the Hypotheses statement
print("Null Hypothesis(H0): The mean weekly operating cost is less than or equal to Rs.4000.")
print("Alternative Hypothesis(H1): The mean weekly operating cost is greater than 4000.")

#Data
sample_mean=3050
theoretical_mean=1000 + 5 * 6000
std_dev=5 * 25
n=25

### 2. Calculate the test statistics
z=(sample_mean-theoretical_mean)/(std_dev/(n**0.5))
print("Test statistics of (z): {z:.4f}")

###3. Determine the Critical value
alpha=0.05
z_critical=stats.norm.ppf(1-alpha)
print(f"Critical Value (z at alpha=0.05): {z_critical:.4f}")

### 4. Decision
if z>z_critical:
    print("Result: Reject NULL Hypothesis.")
    print("Conclusion: There IS strong evidance that the weekly operating cost is higher than the model suggests.")

else:
    print("Result: Fail to reject NULL Hypothesis.")
    print("Conclusion: There is NOT enough evidance to support that the costs are higher than the model.")
# Out:
# Null Hypothesis(H0): The mean weekly operating cost is less than or equal to Rs.4000.
# Alternative Hypothesis(H1): The mean weekly operating cost is greater than 4000.
# Test statistics of (z): {z:.4f}
# Critical Value (z at alpha=0.05): 1.6449
# Result: Fail to reject NULL Hypothesis.
# Conclusion: There is NOT enough evidance to support that the costs are higher than the model.
